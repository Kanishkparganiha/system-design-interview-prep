# %% [markdown]
# # 04 - Stack
#
# A stack is LIFO (last-in, first-out). In Python, use a plain `list` — `append()` pushes, `pop()` pops from the end.
#
# Stacks appear in: bracket matching, expression evaluation, monotonic problems, and DFS.
#
# **Problems in this notebook:**
# 1. Valid Parentheses *(Easy)*
# 2. Min Stack *(Medium)*
# 3. Evaluate Reverse Polish Notation *(Medium)*
# 4. Daily Temperatures *(Medium)*
# 5. Largest Rectangle in Histogram *(Hard)*
#
# ---
# **Resources:**
# - [NeetCode - Stack](https://neetcode.io/roadmap)
# - [Monotonic Stack Pattern](https://www.geeksforgeeks.org/introduction-to-monotonic-stack-data-structure/)
# - [Stack Visualizer - VisuAlgo](https://visualgo.net/en/list)

# %% [markdown]
# ---
# ## Problem 1 — Valid Parentheses
# **Difficulty:** Easy
#
# Given a string `s` containing only `(`, `)`, `{`, `}`, `[`, `]`, determine if the input string is valid.
#
# A string is valid if:
# - Open brackets are closed by the same type of bracket
# - Open brackets are closed in the correct order
# - Every close bracket has a corresponding open bracket
#
# **Examples:**
# ```
# Input:  "()"
# Output: True
#
# Input:  "()[]{}"
# Output: True
#
# Input:  "(]"
# Output: False
#
# Input:  "([)]"
# Output: False
# ```
#
# **Constraints:**
# - 1 <= len(s) <= 10^4
# - s consists of parentheses only

# %%
def is_valid(s):
    """
    Args:
        s: str - contains only (){}[]
    Returns:
        bool
    """
    # Your code here
    pass

# %%
# ---- TEST CASES ----
assert is_valid("()") == True,         "Test 1 failed"
assert is_valid("()[]{}") == True,     "Test 2 failed"
assert is_valid("(]") == False,        "Test 3 failed"
assert is_valid("([)]") == False,      "Test 4 failed"
assert is_valid("{[]}") == True,       "Test 5 failed"
assert is_valid("]") == False,         "Test 6 failed (lone close)"
assert is_valid("") == True,           "Test 7 failed (empty)"
assert is_valid("((((") == False,      "Test 8 failed (unclosed)"
print("All tests passed!")

# %% [markdown]
# <details>
# <summary><b>Hints</b></summary>
#
# - Hint 1: Push opening brackets onto the stack.
# - Hint 2: For closing brackets, check if the top of the stack is the matching opener.
# - Hint 3: At the end, the stack must be empty (all openers were closed).
# </details>

# %% [markdown]
# ---
# ## Problem 2 — Min Stack
# **Difficulty:** Medium
#
# Design a stack that supports `push`, `pop`, `top`, and retrieving the **minimum element** in **O(1)** time.
#
# Implement the `MinStack` class:
# - `push(val)` — pushes `val` onto the stack
# - `pop()` — removes the top element
# - `top()` — returns the top element
# - `get_min()` — returns the minimum element in the stack
#
# **Example:**
# ```
# ms = MinStack()
# ms.push(-2)
# ms.push(0)
# ms.push(-3)
# ms.get_min()  # -3
# ms.pop()
# ms.top()      # 0
# ms.get_min()  # -2
# ```
#
# **Constraints:**
# - -2^31 <= val <= 2^31 - 1
# - `pop`, `top`, `get_min` will always be called on non-empty stack

# %%
class MinStack:
    def __init__(self):
        # Your code here
        pass

    def push(self, val):
        # Your code here
        pass

    def pop(self):
        # Your code here
        pass

    def top(self):
        # Your code here
        pass

    def get_min(self):
        # Your code here
        pass

# %%
# ---- TEST CASES ----
ms = MinStack()
ms.push(-2); ms.push(0); ms.push(-3)
assert ms.get_min() == -3, "Test 1 failed"
ms.pop()
assert ms.top() == 0,      "Test 2 failed"
assert ms.get_min() == -2, "Test 3 failed"

ms2 = MinStack()
ms2.push(5); ms2.push(3); ms2.push(7)
assert ms2.get_min() == 3, "Test 4 failed"
ms2.pop()
assert ms2.get_min() == 3, "Test 5 failed (min unchanged after pop)"
ms2.pop()
assert ms2.get_min() == 5, "Test 6 failed (min updated after pop)"

print("All tests passed!")

# %% [markdown]
# <details>
# <summary><b>Hints</b></summary>
#
# - Hint 1: A single extra variable for minimum doesn't work — what if the current min gets popped?
# - Hint 2: Use a second stack that tracks the minimum at each level. When you push, also push the current min onto the min stack.
# - Hint 3: When you pop, pop from both stacks. `get_min()` just peeks the top of the min stack.
# </details>

# %% [markdown]
# ---
# ## Problem 3 — Evaluate Reverse Polish Notation
# **Difficulty:** Medium
#
# Evaluate the value of an arithmetic expression in **Reverse Polish Notation (RPN)**.
#
# Valid operators are `+`, `-`, `*`, `/`. Each operand is an integer or another expression.
# Division truncates toward zero.
#
# **Examples:**
# ```
# Input:  ["2", "1", "+", "3", "*"]
# Output: 9   # (2+1)*3 = 9
#
# Input:  ["4", "13", "5", "/", "+"]
# Output: 6   # 4 + (13/5) = 4 + 2 = 6
#
# Input:  ["10", "6", "9", "3", "+", "-11", "*", "/", "*", "17", "+", "5", "+"]
# Output: 22
# ```
#
# **Constraints:**
# - 1 <= len(tokens) <= 10^4
# - Tokens are valid integers or operators
# - The answer fits in a 32-bit integer
# - Division by zero will never occur

# %%
def eval_rpn(tokens):
    """
    Args:
        tokens: List[str]
    Returns:
        int - result of the RPN expression
    """
    # Your code here
    pass

# %%
# ---- TEST CASES ----
assert eval_rpn(["2", "1", "+", "3", "*"]) == 9,                                               "Test 1 failed"
assert eval_rpn(["4", "13", "5", "/", "+"]) == 6,                                              "Test 2 failed"
assert eval_rpn(["10", "6", "9", "3", "+", "-11", "*", "/", "*", "17", "+", "5", "+"]) == 22, "Test 3 failed"
assert eval_rpn(["3", "4", "-"]) == -1,                                                         "Test 4 failed (subtraction)"
assert eval_rpn(["5"]) == 5,                                                                     "Test 5 failed (single)"
assert eval_rpn(["-3", "4", "+"]) == 1,                                                         "Test 6 failed (negative operand)"
print("All tests passed!")

# %% [markdown]
# <details>
# <summary><b>Hints</b></summary>
#
# - Hint 1: In RPN, operands come before their operator. A stack naturally handles this — push operands, pop two when you see an operator.
# - Hint 2: For division, use `int(a / b)` (not `a // b`) to truncate toward zero for negative numbers.
# - Hint 3: The final result is the only element remaining in the stack.
# </details>

# %% [markdown]
# ---
# ## Problem 4 — Daily Temperatures
# **Difficulty:** Medium
#
# Given an array `temperatures`, return an array `answer` where `answer[i]` is the number of days you have to wait after day `i` to get a warmer temperature. If there is no future warmer day, `answer[i] = 0`.
#
# **Examples:**
# ```
# Input:  [73, 74, 75, 71, 69, 72, 76, 73]
# Output: [1, 1, 4, 2, 1, 1, 0, 0]
#
# Input:  [30, 40, 50, 60]
# Output: [1, 1, 1, 0]
#
# Input:  [30, 60, 90]
# Output: [1, 1, 0]
# ```
#
# **Constraints:**
# - 1 <= len(temperatures) <= 10^5
# - 30 <= temperatures[i] <= 100

# %%
def daily_temperatures(temperatures):
    """
    Args:
        temperatures: List[int]
    Returns:
        List[int] - wait days for warmer temperature
    """
    # Your code here
    pass

# %%
# ---- TEST CASES ----
assert daily_temperatures([73, 74, 75, 71, 69, 72, 76, 73]) == [1, 1, 4, 2, 1, 1, 0, 0], "Test 1 failed"
assert daily_temperatures([30, 40, 50, 60]) == [1, 1, 1, 0],                               "Test 2 failed"
assert daily_temperatures([30, 60, 90]) == [1, 1, 0],                                      "Test 3 failed"
assert daily_temperatures([90, 80, 70]) == [0, 0, 0],                                      "Test 4 failed (decreasing)"
assert daily_temperatures([50]) == [0],                                                     "Test 5 failed (single)"
print("All tests passed!")

# %% [markdown]
# <details>
# <summary><b>Hints</b></summary>
#
# - Hint 1: Use a monotonic stack (decreasing). Store indices, not temperatures.
# - Hint 2: For each temperature, pop indices from the stack while the current temperature is warmer than stack's top. The answer for that popped index = current index - popped index.
# - Hint 3: Remaining indices in the stack at the end get answer 0 (no warmer day found).
# </details>

# %% [markdown]
# ---
# ## Problem 5 — Largest Rectangle in Histogram
# **Difficulty:** Hard
#
# Given an array of integers `heights` representing the histogram's bar heights where the width of each bar is 1, return the area of the **largest rectangle** in the histogram.
#
# **Examples:**
# ```
# Input:  [2, 1, 5, 6, 2, 3]
# Output: 10   # bars at index 2 and 3 (height 5,6): 5*2 = 10
#
# Input:  [2, 4]
# Output: 4
# ```
#
# **Constraints:**
# - 1 <= len(heights) <= 10^5
# - 0 <= heights[i] <= 10^4

# %%
def largest_rectangle_area(heights):
    """
    Args:
        heights: List[int]
    Returns:
        int - area of largest rectangle
    """
    # Your code here
    pass

# %%
# ---- TEST CASES ----
assert largest_rectangle_area([2, 1, 5, 6, 2, 3]) == 10, "Test 1 failed"
assert largest_rectangle_area([2, 4]) == 4,               "Test 2 failed"
assert largest_rectangle_area([1]) == 1,                  "Test 3 failed (single)"
assert largest_rectangle_area([0]) == 0,                  "Test 4 failed (zero height)"
assert largest_rectangle_area([5, 5, 5, 5]) == 20,        "Test 5 failed (all equal)"
assert largest_rectangle_area([1, 2, 3, 4, 5]) == 9,      "Test 6 failed (increasing)"
print("All tests passed!")

# %% [markdown]
# <details>
# <summary><b>Hints</b></summary>
#
# - Hint 1: For each bar, the largest rectangle using that bar's height extends as far left and right as bars of equal or greater height.
# - Hint 2: Use a monotonic stack (increasing). Store `(index, height)` pairs.
# - Hint 3: When you encounter a bar shorter than the stack's top, the top bar can no longer extend right. Pop it and compute its rectangle width using the current index minus the stack's new top index. Push the current bar with the start index of the last popped bar.
# </details>
