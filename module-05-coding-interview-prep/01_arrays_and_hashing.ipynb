# %% [markdown]
# # 01 - Arrays & Hashing
#
# Hash maps and hash sets let you trade space for time — turning O(n²) brute-force solutions into O(n).
# This is the most fundamental pattern in coding interviews.
#
# **Problems in this notebook:**
# 1. Two Sum *(Easy)*
# 2. Contains Duplicate *(Easy)*
# 3. Valid Anagram *(Easy)*
# 4. Group Anagrams *(Medium)*
# 5. Top K Frequent Elements *(Medium)*
# 6. Product of Array Except Self *(Medium)*
#
# ---
# **Resources:**
# - [NeetCode - Arrays & Hashing playlist](https://neetcode.io/roadmap) (select Arrays & Hashing)
# - [Hash Table - VisuAlgo](https://visualgo.net/en/hashtable)
# - [Python dict internals](https://realpython.com/python-hash-table/)

# %% [markdown]
# ---
# ## Problem 1 — Two Sum
# **Difficulty:** Easy
#
# Given an array of integers `nums` and a target integer `target`, return the **indices** of the two numbers that add up to `target`.
#
# You may assume exactly one solution exists. You may not use the same element twice.
# Return indices in any order.
#
# **Examples:**
# ```
# Input:  nums = [2, 7, 11, 15], target = 9
# Output: [0, 1]   # nums[0] + nums[1] = 2 + 7 = 9
#
# Input:  nums = [3, 2, 4], target = 6
# Output: [1, 2]
# ```
#
# **Constraints:**
# - 2 <= len(nums) <= 10^4
# - -10^9 <= nums[i] <= 10^9
# - Exactly one valid answer exists
#
# **Follow-up:** Can you solve it in O(n) time?

# %%
def two_sum(nums, target):
    """
    Args:
        nums:   List[int]
        target: int
    Returns:
        List[int] - two indices whose values sum to target
    """
    # Your code here
    pass

# %%
# ---- TEST CASES — Run this cell to check your solution ----
def check(result, expected):
    return sorted(result) == sorted(expected)

assert check(two_sum([2, 7, 11, 15], 9), [0, 1]), "Test 1 failed"
assert check(two_sum([3, 2, 4], 6), [1, 2]),      "Test 2 failed"
assert check(two_sum([3, 3], 6), [0, 1]),          "Test 3 failed"
assert check(two_sum([1, 5, 3, 7], 8), [1, 3]),   "Test 4 failed"
assert check(two_sum([-1, -2, -3, -4], -3), [0, 1]), "Test 5 failed (negatives)"
print("All tests passed!")

# %% [markdown]
# <details>
# <summary><b>Hints (click to expand)</b></summary>
#
# - Hint 1: Brute force is O(n²) — try all pairs. Can you do better?
# - Hint 2: For each number `x`, you need to find `target - x`. A hash map can do this in O(1).
# - Hint 3: As you iterate, store each number and its index in the map. Before storing, check if the complement already exists.
# </details>

# %% [markdown]
# ---
# ## Problem 2 — Contains Duplicate
# **Difficulty:** Easy
#
# Given an integer array `nums`, return `True` if any value appears **at least twice**, and `False` if every element is distinct.
#
# **Examples:**
# ```
# Input:  [1, 2, 3, 1]
# Output: True
#
# Input:  [1, 2, 3, 4]
# Output: False
#
# Input:  [1, 1, 1, 3, 3, 4, 3, 2, 4, 2]
# Output: True
# ```
#
# **Constraints:**
# - 1 <= len(nums) <= 10^5
# - -10^9 <= nums[i] <= 10^9

# %%
def contains_duplicate(nums):
    """
    Args:
        nums: List[int]
    Returns:
        bool
    """
    # Your code here
    pass

# %%
# ---- TEST CASES ----
assert contains_duplicate([1, 2, 3, 1]) == True,              "Test 1 failed"
assert contains_duplicate([1, 2, 3, 4]) == False,             "Test 2 failed"
assert contains_duplicate([1, 1, 1, 3, 3, 4]) == True,        "Test 3 failed"
assert contains_duplicate([1]) == False,                      "Test 4 failed (single element)"
assert contains_duplicate([-1, -1, 0]) == True,               "Test 5 failed (negatives)"
print("All tests passed!")

# %% [markdown]
# <details>
# <summary><b>Hints</b></summary>
#
# - Hint 1: A set only stores unique elements. What happens when you try to add a duplicate?
# - Hint 2: Compare `len(nums)` vs `len(set(nums))`.
# - Hint 3: For O(n) early exit, add elements to a set one by one and check before inserting.
# </details>

# %% [markdown]
# ---
# ## Problem 3 — Valid Anagram
# **Difficulty:** Easy
#
# Given two strings `s` and `t`, return `True` if `t` is an anagram of `s`, and `False` otherwise.
#
# An anagram is a word formed by rearranging the letters of another, using all original letters exactly once.
#
# **Examples:**
# ```
# Input:  s = "anagram", t = "nagaram"
# Output: True
#
# Input:  s = "rat", t = "car"
# Output: False
# ```
#
# **Constraints:**
# - 1 <= len(s), len(t) <= 5 * 10^4
# - s and t consist of lowercase English letters
#
# **Follow-up:** What if the inputs could contain Unicode characters?

# %%
def is_anagram(s, t):
    """
    Args:
        s: str
        t: str
    Returns:
        bool
    """
    # Your code here
    pass

# %%
# ---- TEST CASES ----
assert is_anagram("anagram", "nagaram") == True,   "Test 1 failed"
assert is_anagram("rat", "car") == False,           "Test 2 failed"
assert is_anagram("a", "a") == True,                "Test 3 failed (single char)"
assert is_anagram("ab", "a") == False,              "Test 4 failed (diff lengths)"
assert is_anagram("listen", "silent") == True,      "Test 5 failed"
assert is_anagram("hello", "world") == False,       "Test 6 failed"
print("All tests passed!")

# %% [markdown]
# <details>
# <summary><b>Hints</b></summary>
#
# - Hint 1: If lengths differ, they can't be anagrams.
# - Hint 2: Count the frequency of each character in both strings and compare.
# - Hint 3: `collections.Counter` builds a frequency map for you. Or use a plain dict.
# </details>

# %% [markdown]
# ---
# ## Problem 4 — Group Anagrams
# **Difficulty:** Medium
#
# Given a list of strings, group the strings that are anagrams of each other. Return the groups in any order.
#
# **Examples:**
# ```
# Input:  ["eat", "tea", "tan", "ate", "nat", "bat"]
# Output: [["eat", "tea", "ate"], ["tan", "nat"], ["bat"]]
#
# Input:  [""]
# Output: [[""]]
#
# Input:  ["a"]
# Output: [["a"]]
# ```
#
# **Constraints:**
# - 1 <= len(strs) <= 10^4
# - 0 <= len(strs[i]) <= 100
# - strs[i] consists of lowercase English letters

# %%
def group_anagrams(strs):
    """
    Args:
        strs: List[str]
    Returns:
        List[List[str]]
    """
    # Your code here
    pass

# %%
# ---- TEST CASES ----
def normalize(groups):
    return sorted([sorted(g) for g in groups])

result = group_anagrams(["eat", "tea", "tan", "ate", "nat", "bat"])
expected = [["ate", "eat", "tea"], ["nat", "tan"], ["bat"]]
assert normalize(result) == normalize(expected), "Test 1 failed"

assert normalize(group_anagrams([""])) == normalize([[""]]), "Test 2 failed"
assert normalize(group_anagrams(["a"])) == normalize([["a"]]), "Test 3 failed"

result2 = group_anagrams(["abc", "bca", "xyz", "zyx", "cab"])
expected2 = [["abc", "bca", "cab"], ["xyz", "zyx"]]
assert normalize(result2) == normalize(expected2), "Test 4 failed"

print("All tests passed!")

# %% [markdown]
# <details>
# <summary><b>Hints</b></summary>
#
# - Hint 1: Two strings are anagrams if and only if their sorted characters are equal.
# - Hint 2: Use a hash map where the key is the sorted string and value is a list of matching words.
# - Hint 3: `from collections import defaultdict` makes grouping easier.
# </details>

# %% [markdown]
# ---
# ## Problem 5 — Top K Frequent Elements
# **Difficulty:** Medium
#
# Given an integer array `nums` and an integer `k`, return the `k` most frequent elements. You may return the answer in any order.
#
# **Examples:**
# ```
# Input:  nums = [1, 1, 1, 2, 2, 3], k = 2
# Output: [1, 2]
#
# Input:  nums = [1], k = 1
# Output: [1]
# ```
#
# **Constraints:**
# - 1 <= len(nums) <= 10^5
# - k is in the range [1, number of unique elements]
# - The answer is guaranteed to be unique
#
# **Follow-up:** Can you solve it in O(n) time? (Hint: bucket sort)

# %%
def top_k_frequent(nums, k):
    """
    Args:
        nums: List[int]
        k:    int
    Returns:
        List[int]
    """
    # Your code here
    pass

# %%
# ---- TEST CASES ----
assert sorted(top_k_frequent([1, 1, 1, 2, 2, 3], 2)) == [1, 2], "Test 1 failed"
assert sorted(top_k_frequent([1], 1)) == [1],                   "Test 2 failed"
assert sorted(top_k_frequent([4, 4, 4, 6, 6, 7], 1)) == [4],   "Test 3 failed"
assert sorted(top_k_frequent([1, 2], 2)) == [1, 2],             "Test 4 failed (all equal freq)"
assert sorted(top_k_frequent([5, 5, 4, 4, 3], 2)) == [4, 5],   "Test 5 failed"
print("All tests passed!")

# %% [markdown]
# <details>
# <summary><b>Hints</b></summary>
#
# - Hint 1: First count frequencies using a dict or `Counter`.
# - Hint 2: Use a heap (`heapq.nlargest`) to get top-k by frequency — O(n log k).
# - Hint 3: For O(n): bucket sort — create a list of size n+1 where index = frequency, then scan from right.
# </details>

# %% [markdown]
# ---
# ## Problem 6 — Product of Array Except Self
# **Difficulty:** Medium
#
# Given an integer array `nums`, return an array `output` where `output[i]` is the product of all elements of `nums` **except** `nums[i]`.
#
# You must solve it in **O(n)** time without using division.
#
# **Examples:**
# ```
# Input:  [1, 2, 3, 4]
# Output: [24, 12, 8, 6]
#
# Input:  [-1, 1, 0, -3, 3]
# Output: [0, 0, 9, 0, 0]
# ```
#
# **Constraints:**
# - 2 <= len(nums) <= 10^5
# - -30 <= nums[i] <= 30
# - The product of any prefix or suffix of nums fits in a 32-bit integer
#
# **Follow-up:** Solve it with O(1) extra space (excluding the output array).

# %%
def product_except_self(nums):
    """
    Args:
        nums: List[int]
    Returns:
        List[int]
    """
    # Your code here
    pass

# %%
# ---- TEST CASES ----
assert product_except_self([1, 2, 3, 4]) == [24, 12, 8, 6],          "Test 1 failed"
assert product_except_self([-1, 1, 0, -3, 3]) == [0, 0, 9, 0, 0],   "Test 2 failed"
assert product_except_self([1, 1]) == [1, 1],                         "Test 3 failed"
assert product_except_self([2, 3, 4]) == [12, 8, 6],                  "Test 4 failed"
assert product_except_self([0, 0]) == [0, 0],                         "Test 5 failed (zeros)"
print("All tests passed!")

# %% [markdown]
# <details>
# <summary><b>Hints</b></summary>
#
# - Hint 1: `output[i]` = (product of all elements to the left of i) * (product of all elements to the right of i).
# - Hint 2: Do two passes — first compute left products, then multiply in right products.
# - Hint 3: For O(1) space: store left products in the output array, then do a right pass with a running variable.
# </details>
