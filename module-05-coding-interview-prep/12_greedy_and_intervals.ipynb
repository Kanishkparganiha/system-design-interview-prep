# %% [markdown]
# # 12 - Greedy & Intervals
#
# **Greedy:** Make the locally optimal choice at each step, hoping it leads to a globally optimal solution. Works when a greedy choice property holds — proving it requires care.
#
# **Interval problems** often reduce to: sort by start or end time, then apply a greedy strategy.
#
# **Problems in this notebook:**
# 1. Jump Game *(Medium)*
# 2. Jump Game II *(Medium)*
# 3. Merge Intervals *(Medium)*
# 4. Non-overlapping Intervals *(Medium)*
# 5. Meeting Rooms *(Easy)*
#
# ---
# **Resources:**
# - [NeetCode - Greedy](https://neetcode.io/roadmap)
# - [Interval Scheduling - GeeksForGeeks](https://www.geeksforgeeks.org/activity-selection-problem-greedy-algo-1/)

# %% [markdown]
# ---
# ## Problem 1 — Jump Game
# **Difficulty:** Medium
#
# You are at index 0 of an array `nums`. `nums[i]` is the maximum jump length from index `i`. Return `True` if you can reach the last index.
#
# **Examples:**
# ```
# Input:  [2, 3, 1, 1, 4]
# Output: True   # Jump 1 to index 1, then 3 to last
#
# Input:  [3, 2, 1, 0, 4]
# Output: False  # Always stuck at index 3
# ```
#
# **Constraints:**
# - 1 <= len(nums) <= 3 * 10^4
# - 0 <= nums[i] <= 10^5

# %%
def can_jump(nums):
    """
    Args:
        nums: List[int]
    Returns:
        bool
    """
    # Your code here
    pass

# %%
# ---- TEST CASES ----
assert can_jump([2,3,1,1,4]) == True,    "Test 1 failed"
assert can_jump([3,2,1,0,4]) == False,   "Test 2 failed (stuck at 0)"
assert can_jump([0]) == True,            "Test 3 failed (already at end)"
assert can_jump([1,0]) == True,          "Test 4 failed"
assert can_jump([0,1]) == False,         "Test 5 failed (0 jump from start)"
assert can_jump([1,1,1,0]) == True,      "Test 6 failed"
print("All tests passed!")

# %% [markdown]
# <details>
# <summary><b>Hints</b></summary>
#
# - Hint 1: Track the farthest index reachable so far (`max_reach`).
# - Hint 2: For each index `i`, if `i > max_reach`, you're stuck — return False.
# - Hint 3: Otherwise update `max_reach = max(max_reach, i + nums[i])`. If `max_reach >= last_index`, return True.
# </details>

# %% [markdown]
# ---
# ## Problem 2 — Jump Game II
# **Difficulty:** Medium
#
# Same setup as Jump Game. You are guaranteed to reach the last index. Return the **minimum number of jumps** to reach it.
#
# **Examples:**
# ```
# Input:  [2, 3, 1, 1, 4]
# Output: 2   # Jump to index 1, then to last
#
# Input:  [2, 3, 0, 1, 4]
# Output: 2
# ```
#
# **Constraints:**
# - 1 <= len(nums) <= 3 * 10^4
# - 0 <= nums[i] <= 10^5
# - It is guaranteed you can reach the last index

# %%
def jump(nums):
    """
    Args:
        nums: List[int]
    Returns:
        int - minimum jumps to reach last index
    """
    # Your code here
    pass

# %%
# ---- TEST CASES ----
assert jump([2,3,1,1,4]) == 2,    "Test 1 failed"
assert jump([2,3,0,1,4]) == 2,    "Test 2 failed"
assert jump([0]) == 0,             "Test 3 failed (already at end)"
assert jump([1,2,3]) == 2,        "Test 4 failed"
assert jump([1,1,1,1]) == 3,      "Test 5 failed"
assert jump([5,9,3,2,1,0,2,3,3,1,0,0]) == 2, "Test 6 failed"
print("All tests passed!")

# %% [markdown]
# <details>
# <summary><b>Hints</b></summary>
#
# - Hint 1: Think of it in "layers" like BFS. `current_end` is the farthest you can reach with current jumps. `farthest` is the farthest you could reach with one more jump.
# - Hint 2: When you reach `current_end`, you must jump — increment jump count and set `current_end = farthest`.
# - Hint 3: Scan left to right, updating `farthest = max(farthest, i + nums[i])`. When `i == current_end`, take a jump.
# </details>

# %% [markdown]
# ---
# ## Problem 3 — Merge Intervals
# **Difficulty:** Medium
#
# Given an array of intervals `[start, end]`, merge all overlapping intervals and return the result.
#
# **Examples:**
# ```
# Input:  [[1,3],[2,6],[8,10],[15,18]]
# Output: [[1,6],[8,10],[15,18]]
#
# Input:  [[1,4],[4,5]]
# Output: [[1,5]]  # touching intervals merge
# ```
#
# **Constraints:**
# - 1 <= len(intervals) <= 10^4
# - intervals[i].length == 2
# - 0 <= start <= end <= 10^4

# %%
def merge_intervals(intervals):
    """
    Args:
        intervals: List[List[int]]
    Returns:
        List[List[int]] - merged intervals
    """
    # Your code here
    pass

# %%
# ---- TEST CASES ----
assert merge_intervals([[1,3],[2,6],[8,10],[15,18]]) == [[1,6],[8,10],[15,18]], "Test 1 failed"
assert merge_intervals([[1,4],[4,5]]) == [[1,5]],                               "Test 2 failed (touching)"
assert merge_intervals([[1,4],[0,4]]) == [[0,4]],                               "Test 3 failed (unordered)"
assert merge_intervals([[1,4],[2,3]]) == [[1,4]],                               "Test 4 failed (contained)"
assert merge_intervals([[1,2]]) == [[1,2]],                                     "Test 5 failed (single)"
print("All tests passed!")

# %% [markdown]
# <details>
# <summary><b>Hints</b></summary>
#
# - Hint 1: Sort intervals by start time.
# - Hint 2: Start with the first interval. For each next interval, if it overlaps with the current (next start <= current end), merge by extending the end.
# - Hint 3: Otherwise, push the current interval to results and start tracking the new one.
# </details>

# %% [markdown]
# ---
# ## Problem 4 — Non-overlapping Intervals
# **Difficulty:** Medium
#
# Given an array of intervals, return the **minimum number of intervals to remove** to make the rest non-overlapping.
#
# **Examples:**
# ```
# Input:  [[1,2],[2,3],[3,4],[1,3]]
# Output: 1   # Remove [1,3]
#
# Input:  [[1,2],[1,2],[1,2]]
# Output: 2   # Remove two of the three
#
# Input:  [[1,2],[2,3]]
# Output: 0   # Already non-overlapping
# ```
#
# **Constraints:**
# - 1 <= len(intervals) <= 10^5
# - -5 * 10^4 <= start < end <= 5 * 10^4

# %%
def erase_overlap_intervals(intervals):
    """
    Args:
        intervals: List[List[int]]
    Returns:
        int - minimum intervals to remove
    """
    # Your code here
    pass

# %%
# ---- TEST CASES ----
assert erase_overlap_intervals([[1,2],[2,3],[3,4],[1,3]]) == 1, "Test 1 failed"
assert erase_overlap_intervals([[1,2],[1,2],[1,2]]) == 2,       "Test 2 failed"
assert erase_overlap_intervals([[1,2],[2,3]]) == 0,             "Test 3 failed (no removal needed)"
assert erase_overlap_intervals([[0,2],[1,3],[2,4],[3,5],[4,6]]) == 2, "Test 4 failed"
print("All tests passed!")

# %% [markdown]
# <details>
# <summary><b>Hints</b></summary>
#
# - Hint 1: This is equivalent to finding the maximum number of non-overlapping intervals you can KEEP (then subtract from total).
# - Hint 2: Sort by **end time** (greedy: keep the interval that ends earliest — leaves most room for future intervals).
# - Hint 3: Scan sorted intervals. Keep track of `prev_end`. If current start >= prev_end, keep it and update prev_end. Otherwise, remove it (increment counter).
# </details>

# %% [markdown]
# ---
# ## Problem 5 — Meeting Rooms
# **Difficulty:** Easy
#
# Given an array of meeting time intervals `[start, end]`, determine if a person can attend **all meetings** (no two meetings overlap).
#
# **Examples:**
# ```
# Input:  [[0,30],[5,10],[15,20]]
# Output: False  # [0,30] and [5,10] overlap
#
# Input:  [[7,10],[2,4]]
# Output: True
# ```
#
# **Constraints:**
# - 0 <= len(intervals) <= 5 * 10^4
# - 0 <= start < end <= 10^6
#
# **Follow-up:** What is the minimum number of rooms needed to hold all meetings? (Meeting Rooms II)

# %%
def can_attend_meetings(intervals):
    """
    Args:
        intervals: List[List[int]]
    Returns:
        bool
    """
    # Your code here
    pass

# %%
# ---- TEST CASES ----
assert can_attend_meetings([[0,30],[5,10],[15,20]]) == False, "Test 1 failed"
assert can_attend_meetings([[7,10],[2,4]]) == True,           "Test 2 failed"
assert can_attend_meetings([]) == True,                       "Test 3 failed (empty)"
assert can_attend_meetings([[1,2],[2,3]]) == True,            "Test 4 failed (touching OK)"
assert can_attend_meetings([[1,5],[6,10],[3,8]]) == False,   "Test 5 failed"
print("All tests passed!")

# %% [markdown]
# <details>
# <summary><b>Hints</b></summary>
#
# - Hint 1: Sort by start time.
# - Hint 2: Check if any meeting starts before the previous one ends: `intervals[i][0] < intervals[i-1][1]`.
# - Hint 3 (Follow-up — Meeting Rooms II): Use a min-heap of end times. For each meeting, if the earliest-ending meeting finishes before this one starts, reuse that room (pop and push new end). Otherwise, add a new room (push).
# </details>
