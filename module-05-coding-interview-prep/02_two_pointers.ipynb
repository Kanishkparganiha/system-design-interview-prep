# %% [markdown]
# # 02 - Two Pointers
#
# The two-pointer technique uses two indices that move toward (or away from) each other to reduce nested loops.
# It works best on **sorted arrays** or problems where you want to shrink a search space.
#
# **Problems in this notebook:**
# 1. Valid Palindrome *(Easy)*
# 2. Two Sum II — Sorted Input *(Medium)*
# 3. Three Sum *(Medium)*
# 4. Container With Most Water *(Medium)*
# 5. Trapping Rain Water *(Hard)*
#
# ---
# **Resources:**
# - [NeetCode - Two Pointers](https://neetcode.io/roadmap)
# - [Two Pointers Pattern - GeeksForGeeks](https://www.geeksforgeeks.org/two-pointers-technique/)

# %% [markdown]
# ---
# ## Problem 1 — Valid Palindrome
# **Difficulty:** Easy
#
# A phrase is a palindrome if, after converting all uppercase letters to lowercase and removing all non-alphanumeric characters, it reads the same forward and backward.
#
# Given a string `s`, return `True` if it is a palindrome, `False` otherwise.
#
# **Examples:**
# ```
# Input:  "A man, a plan, a canal: Panama"
# Output: True   # "amanaplanacanalpanama"
#
# Input:  "race a car"
# Output: False  # "raceacar"
#
# Input:  " "
# Output: True   # empty after filtering
# ```
#
# **Constraints:**
# - 1 <= len(s) <= 2 * 10^5
# - s consists only of printable ASCII characters

# %%
def is_palindrome(s):
    """
    Args:
        s: str
    Returns:
        bool
    """
    # Your code here
    pass

# %%
# ---- TEST CASES ----
assert is_palindrome("A man, a plan, a canal: Panama") == True,  "Test 1 failed"
assert is_palindrome("race a car") == False,                      "Test 2 failed"
assert is_palindrome(" ") == True,                                "Test 3 failed (whitespace only)"
assert is_palindrome("racecar") == True,                          "Test 4 failed"
assert is_palindrome("0P") == False,                              "Test 5 failed (mixed)"
assert is_palindrome("a") == True,                                "Test 6 failed (single char)"
print("All tests passed!")

# %% [markdown]
# <details>
# <summary><b>Hints</b></summary>
#
# - Hint 1: Use `str.isalnum()` to filter characters and `str.lower()` to normalize.
# - Hint 2: Two pointers — left starts at 0, right starts at end. Skip non-alphanumeric, compare chars.
# - Hint 3: If chars don't match at any step, return False immediately.
# </details>

# %% [markdown]
# ---
# ## Problem 2 — Two Sum II (Sorted Input)
# **Difficulty:** Medium
#
# Given a **1-indexed** sorted array `numbers` and a `target`, return the indices of the two numbers that sum to `target` as `[index1, index2]` (1-indexed).
#
# You must use **O(1) extra space**.
#
# **Examples:**
# ```
# Input:  numbers = [2, 7, 11, 15], target = 9
# Output: [1, 2]
#
# Input:  numbers = [2, 3, 4], target = 6
# Output: [1, 3]
#
# Input:  numbers = [-1, 0], target = -1
# Output: [1, 2]
# ```
#
# **Constraints:**
# - 2 <= len(numbers) <= 3 * 10^4
# - Numbers are sorted in non-decreasing order
# - Exactly one solution exists

# %%
def two_sum_sorted(numbers, target):
    """
    Args:
        numbers: List[int] - sorted in non-decreasing order
        target:  int
    Returns:
        List[int] - 1-indexed [i, j] where numbers[i-1] + numbers[j-1] == target
    """
    # Your code here
    pass

# %%
# ---- TEST CASES ----
assert two_sum_sorted([2, 7, 11, 15], 9) == [1, 2],  "Test 1 failed"
assert two_sum_sorted([2, 3, 4], 6) == [1, 3],        "Test 2 failed"
assert two_sum_sorted([-1, 0], -1) == [1, 2],         "Test 3 failed"
assert two_sum_sorted([1, 2, 3, 4, 5], 9) == [4, 5], "Test 4 failed"
assert two_sum_sorted([1, 3, 4, 5, 7, 11], 9) == [3, 4], "Test 5 failed"
print("All tests passed!")

# %% [markdown]
# <details>
# <summary><b>Hints</b></summary>
#
# - Hint 1: Since the array is sorted, use left and right pointers.
# - Hint 2: If `numbers[left] + numbers[right] < target`, move left forward (need bigger sum).
# - Hint 3: If the sum is too big, move right backward. If equal, return both (add 1 for 1-indexing).
# </details>

# %% [markdown]
# ---
# ## Problem 3 — Three Sum
# **Difficulty:** Medium
#
# Given an integer array `nums`, return all triplets `[nums[i], nums[j], nums[k]]` such that `i != j != k != i` and `nums[i] + nums[j] + nums[k] == 0`.
#
# The solution set must **not contain duplicate triplets**.
#
# **Examples:**
# ```
# Input:  [-1, 0, 1, 2, -1, -4]
# Output: [[-1, -1, 2], [-1, 0, 1]]
#
# Input:  [0, 1, 1]
# Output: []
#
# Input:  [0, 0, 0]
# Output: [[0, 0, 0]]
# ```
#
# **Constraints:**
# - 3 <= len(nums) <= 3000
# - -10^5 <= nums[i] <= 10^5

# %%
def three_sum(nums):
    """
    Args:
        nums: List[int]
    Returns:
        List[List[int]] - unique triplets that sum to zero
    """
    # Your code here
    pass

# %%
# ---- TEST CASES ----
def normalize_triplets(triplets):
    return sorted([sorted(t) for t in triplets])

assert normalize_triplets(three_sum([-1, 0, 1, 2, -1, -4])) == [[-1, -1, 2], [-1, 0, 1]], "Test 1 failed"
assert normalize_triplets(three_sum([0, 1, 1])) == [],                                     "Test 2 failed"
assert normalize_triplets(three_sum([0, 0, 0])) == [[0, 0, 0]],                            "Test 3 failed"
assert normalize_triplets(three_sum([-2, 0, 0, 2, 2])) == [[-2, 0, 2]],                   "Test 4 failed (dedup)"
print("All tests passed!")

# %% [markdown]
# <details>
# <summary><b>Hints</b></summary>
#
# - Hint 1: Sort the array first. This makes deduplication and two-pointer easy.
# - Hint 2: Fix one element `nums[i]`, then use two pointers on the rest to find pairs summing to `-nums[i]`.
# - Hint 3: Skip duplicates: after processing index `i`, skip if `nums[i] == nums[i-1]`. Do the same for left/right pointers after finding a match.
# </details>

# %% [markdown]
# ---
# ## Problem 4 — Container With Most Water
# **Difficulty:** Medium
#
# You are given an integer array `height` of length `n`. There are `n` vertical lines where the `i`-th line has height `height[i]`. Find two lines that together with the x-axis form a container holding the most water.
#
# Return the maximum amount of water the container can hold.
#
# **Examples:**
# ```
# Input:  [1, 8, 6, 2, 5, 4, 8, 3, 7]
# Output: 49   # lines at index 1 and 8: min(8,7) * (8-1) = 7*7 = 49
#
# Input:  [1, 1]
# Output: 1
# ```
#
# **Constraints:**
# - 2 <= len(height) <= 10^5
# - 0 <= height[i] <= 10^4

# %%
def max_area(height):
    """
    Args:
        height: List[int]
    Returns:
        int - maximum water contained
    """
    # Your code here
    pass

# %%
# ---- TEST CASES ----
assert max_area([1, 8, 6, 2, 5, 4, 8, 3, 7]) == 49, "Test 1 failed"
assert max_area([1, 1]) == 1,                         "Test 2 failed"
assert max_area([4, 3, 2, 1, 4]) == 16,               "Test 3 failed"
assert max_area([1, 2, 1]) == 2,                      "Test 4 failed"
assert max_area([2, 3, 4, 5, 18, 17, 6]) == 17,      "Test 5 failed"
print("All tests passed!")

# %% [markdown]
# <details>
# <summary><b>Hints</b></summary>
#
# - Hint 1: Water = `min(height[left], height[right]) * (right - left)`.
# - Hint 2: Start with pointers at both ends. To potentially increase water, move the pointer at the shorter line inward.
# - Hint 3: Moving the taller line inward can only decrease width AND keep height bounded — so always move the shorter one.
# </details>

# %% [markdown]
# ---
# ## Problem 5 — Trapping Rain Water
# **Difficulty:** Hard
#
# Given `n` non-negative integers representing an elevation map where each bar has width 1, compute how much water it can trap after raining.
#
# **Examples:**
# ```
# Input:  [0, 1, 0, 2, 1, 0, 1, 3, 2, 1, 2, 1]
# Output: 6
#
# Input:  [4, 2, 0, 3, 2, 5]
# Output: 9
# ```
#
# **Constraints:**
# - n == len(height)
# - 1 <= n <= 2 * 10^4
# - 0 <= height[i] <= 10^5

# %%
def trap(height):
    """
    Args:
        height: List[int]
    Returns:
        int - total units of trapped water
    """
    # Your code here
    pass

# %%
# ---- TEST CASES ----
assert trap([0, 1, 0, 2, 1, 0, 1, 3, 2, 1, 2, 1]) == 6, "Test 1 failed"
assert trap([4, 2, 0, 3, 2, 5]) == 9,                    "Test 2 failed"
assert trap([3, 0, 2, 0, 4]) == 7,                        "Test 3 failed"
assert trap([1, 0, 1]) == 1,                              "Test 4 failed"
assert trap([0, 0, 0]) == 0,                              "Test 5 failed (no water)"
assert trap([3]) == 0,                                    "Test 6 failed (single bar)"
print("All tests passed!")

# %% [markdown]
# <details>
# <summary><b>Hints</b></summary>
#
# - Hint 1: Water at position `i` = `min(max_left, max_right) - height[i]`. Can you precompute max_left and max_right arrays?
# - Hint 2: The precompute approach is O(n) time O(n) space. For O(1) space: two pointers.
# - Hint 3: Two pointer approach — maintain `left_max` and `right_max`. Process whichever side has the smaller max (it's the bottleneck). The water at that bar is `max - height[pointer]`.
# </details>
